# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
results = pd.read_csv(r'C:\Users\LENOVO\Cloned repos\atari\Atari\results\experiment_results.csv')

# Display the first few rows of the dataset
print(results.head())
# Out:
#    Exp     Policy      lr  gamma  batch_size  expl_fraction  expl_initial_eps  \
# 0    1  CnnPolicy  0.0001   0.99          32            0.1               1.0
#
#    expl_final_eps  Mean Reward  Std Reward  Mean Ep Length  Time (min)  \
# 0            0.01        210.0         0.0           82.55         0.0
#
#                         Description
# 0  Baseline (RL Zoo Atari defaults)
